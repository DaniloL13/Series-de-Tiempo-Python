# %% [markdown]
# ### IMPORTACIÓN DE PAQUETES

# %%
import pandas as pd
from fbprophet import Prophet

# %% [markdown]
# ### DATA

# %%
df = pd.read_csv('/content/Liquor.csv')
df.columns = ['ds','y']
df['ds'] = pd.to_datetime(df['ds'])
df.head()
# Out:
#           ds     y
# 0 1992-01-01  1509
# 1 1992-02-01  1541
# 2 1992-03-01  1597
# 3 1992-04-01  1675
# 4 1992-05-01  1822

# %% [markdown]
# ### MODELO

# %%
modelo = Prophet()
modelo.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ### PREDICCIÓN

# %% [markdown]
# #### Paso 1: Crear el dataframe donde colocaremos los resultados

# %%
future = modelo.make_future_dataframe(periods=36,freq = 'MS')
future.head()
# Out:
#           ds
# 0 1992-01-01
# 1 1992-02-01
# 2 1992-03-01
# 3 1992-04-01
# 4 1992-05-01

# %%
df.tail()
# Out:
#             ds     y
# 319 2018-08-01  4898
# 320 2018-09-01  4598
# 321 2018-10-01  4737
# 322 2018-11-01  5130
# 323 2018-12-01  6370

# %%
future.tail()
# Out:
#             ds
# 355 2021-08-01
# 356 2021-09-01
# 357 2021-10-01
# 358 2021-11-01
# 359 2021-12-01

# %% [markdown]
# #### Paso 2: Realizar los pronósticos y guardarlos en forecast

# %%
forecast = modelo.predict(future)
forecast.tail()
# Out:
#             ds        trend  ...  multiplicative_terms_upper         yhat
# 355 2021-08-01  5389.825785  ...                         0.0  5428.817628
# 356 2021-09-01  5405.889555  ...                         0.0  5277.289465
# 357 2021-10-01  5421.435139  ...                         0.0  5374.956638
# 358 2021-11-01  5437.498909  ...                         0.0  5504.716419
# 359 2021-12-01  5453.044493  ...                         0.0  6540.517778
#
# [5 rows x 16 columns]

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(12)
# Out:
#             ds         yhat   yhat_lower   yhat_upper
# 348 2021-01-01  4834.369868  4656.429234  4977.854907
# 349 2021-02-01  4806.055989  4630.367838  4976.411029
# 350 2021-03-01  5117.627640  4973.813934  5284.831427
# 351 2021-04-01  5124.037916  4971.117626  5291.808713
# 352 2021-05-01  5385.689353  5221.957988  5558.459874
# 353 2021-06-01  5369.313031  5203.387693  5532.542577
# 354 2021-07-01  5506.439404  5340.316266  5672.232636
# 355 2021-08-01  5428.817628  5272.640057  5593.312516
# 356 2021-09-01  5277.289465  5105.305898  5436.213539
# 357 2021-10-01  5374.956638  5198.421101  5546.860307
# 358 2021-11-01  5504.716419  5331.374981  5673.877974
# 359 2021-12-01  6540.517778  6369.954276  6703.751879

# %% [markdown]
# #### Paso 3: Graficar los pronósticos

# %%
modelo.plot(forecast);

# %%
pd.plotting.register_matplotlib_converters()

# %%
import matplotlib.pyplot as plt
modelo.plot(forecast)
plt.xlim('2014-01-01','2022-01-01')
# Out:
# (735234.0, 738156.0)

# %%
forecast.plot(x='ds',y='yhat')

# %%
modelo.plot_components(forecast);
